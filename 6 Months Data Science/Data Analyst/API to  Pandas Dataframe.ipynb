# %%
import requests
import pandas as pd

# %%
requests.get('https://api.themoviedb.org/3/movie/popular?api_key=92f1ee8c9fe7fc210afad22f8a19ae33&language=en-US&page=10')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=92f1ee8c9fe7fc210afad22f8a19ae33&language=en-US&page=10').json()

# %%
response
# Out:
# {'page': 10,
#  'results': [{'adult': False,
#    'backdrop_path': '/6yIdUIeAXfqUzH93CGDWHsj44AG.jpg',
#    'genre_ids': [53, 27],
#    'id': 360784,
#    'original_language': 'en',
#    'original_title': 'Hidden',
#    'overview': 'A family takes refuge in a fallout shelter to avoid a dangerous outbreak.',
#    'popularity': 219.328,
#    'poster_path': '/oiNc4aTeaUMVNkxL0UWnezmKJgM.jpg',
#    'release_date': '2015-09-15',
#    'title': 'Hidden',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 678},
#   {'adult': False,
#    'backdrop_path': '/ceSQcIWWKSwubn4ny8BlWtE5q7u.jpg',
#    'genre_ids': [53, 27, 18],
#    'id': 852485,
#    'original_language': 'en',
#    'original_title': 'She Will',
#    'overview': 'Veronica, an aging film star, retreats to the Scottish countryside with her nurse Desi to recover from  a double mastectomy. While there, mysterious forces give Veronica the power to enact revenge within her dreams.',
#    'popularity': 384.286,
# ...

# %%
for i in response['results']:
    print(i['title'])
# Out:
# Hidden
# She Will
# Predator
# PAW Patrol: The Movie
# Dragon Ball Z: Super Android 13!
# Free Guy
# Fate/Grand Order: The Movie – Divine Realm of the Round Table: Camelot – Paladin; Agateram
# Harry Potter and the Half-Blood Prince
# Predators
# Harry Potter and the Prisoner of Azkaban
# Harry Potter and the Philosopher's Stone
# The Mystic Nine: Begonia from Qingshan
# Harry Potter and the Deathly Hallows: Part 2
# Counting Sheep
# Girlfriends and Girlfriends
# Dragon Ball Z: Broly – Second Coming
# War of the Worlds: Annihilation
# Beyond Infinity: Buzz and the Journey to Lightyear
# Gold
# Moonbound

# %%
for i in response['results']:
    print(i['title'], i['vote_average'])
# Out:
# Hidden 6.8
# She Will 6
# Predator 7.5
# PAW Patrol: The Movie 7.4
# Dragon Ball Z: Super Android 13! 6.7
# Free Guy 7.6
# Fate/Grand Order: The Movie – Divine Realm of the Round Table: Camelot – Paladin; Agateram 6.2
# Harry Potter and the Half-Blood Prince 7.7
# Predators 6.2
# Harry Potter and the Prisoner of Azkaban 8
# Harry Potter and the Philosopher's Stone 7.9
# The Mystic Nine: Begonia from Qingshan 4.4
# Harry Potter and the Deathly Hallows: Part 2 8.1
# Counting Sheep 6
# Girlfriends and Girlfriends 6.3
# Dragon Ball Z: Broly – Second Coming 6.7
# War of the Worlds: Annihilation 5.4
# Beyond Infinity: Buzz and the Journey to Lightyear 7.1
# Gold 6.3
# Moonbound 6.3

# %%
df = pd.DataFrame()

# %%
#Example for creating Dataframe:-

d = {'name':['Rahul', 'Rohit'], 'Age': [34, 56]}

df = pd.DataFrame(d)

df
# Out:
#     name  Age
# 0  Rahul   34
# 1  Rohit   56

# %%
popularity = []
vote_count = []
original_language = []
title = []
vote_average = []
overview = []
release_date =[]

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d = {'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_average':vote_average}
  

df = pd.DataFrame(d)
 
df
# Out:
#                                                 title  \
# 0                                              Hidden
# 1                                            She Will
# 2                                            Predator
# 3                               PAW Patrol: The Movie
# 4                    Dragon Ball Z: Super Android 13!
# 5                                            Free Guy
# 6   Fate/Grand Order: The Movie – Divine Realm of ...
# 7              Harry Potter and the Half-Blood Prince
# 8                                           Predators
# 9            Harry Potter and the Prisoner of Azkaban
# 10           Harry Potter and the Philosopher's Stone
# 11             The Mystic Nine: Begonia from Qingshan
# 12       Harry Potter and the Deathly Hallows: Part 2
# 13                                     Counting Sheep
# 14                        Girlfriends and Girlfriends
# 15               Dragon Ball Z: Broly – Second Coming
# ...

# %%
Final = pd.DataFrame()

for j in range(1,20):
    
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=92f1ee8c9fe7fc210afad22f8a19ae33&language=en-US&page={}'.format(j)).json()
    
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_date =[]
    
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])
        
        d = {'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_average':vote_average}
        
        df = pd.DataFrame(d)
        
        Final = Final.append(df, ignore_index=True)

# %%
Final
# Out:
#                               title  \
# 0     Dragon Ball Super: Super Hero
# 1     Dragon Ball Super: Super Hero
# 2                              Prey
# 3     Dragon Ball Super: Super Hero
# 4                              Prey
# ...                             ...
# 3985                           Fury
# 3986       Three Steps Above Heaven
# 3987                        Demonic
# 3988             Sonic the Hedgehog
# 3989       Dragon Ball Z: Bio-Broly
#
#                                                overview original_language  \
# 0     The Red Ribbon Army, an evil organization that...                ja
# 1     The Red Ribbon Army, an evil organization that...                ja
# 2     When danger threatens her camp, the fierce and...                en
# 3     The Red Ribbon Army, an evil organization that...                ja
# 4     When danger threatens her camp, the fierce and...                en
# ...                                                 ...               ...
# ...

# %%
Final.to_csv('TMBD_movies.csv')
